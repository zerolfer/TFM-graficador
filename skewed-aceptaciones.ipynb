# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
df = pd.read_csv(
    "C:\\Users\\Administrador\\Documents\\Proyecto-Salomon\\resultados\\Caso1Id1m-01-01-2019\\VNS\\Trazas\\output1.csv",
    sep=';', skiprows=[0],
    names=["iteracion", "tiempo (ms)", "fitness total", "fitness 1", "fitness 2", "fitness 3", "fitness 4", "tamaño",
           "porcentajeMejora", "vecindad", "mejor fitness", "distancia"])

df2 = df.copy(deep=True)
df2.apply(lambda row: round(float(row["mejor fitness"]), 6), axis=1)
df2['diferentes'] = df.apply(lambda row: row["fitness total"] != row["mejor fitness"], axis=1)

df2[["fitness total", "mejor fitness", "diferentes"]]
# Out:
#       fitness total  mejor fitness  diferentes
# 0          0.609488       0.609488       False
# 1          0.609488       0.609488       False
# 2          0.938827       0.938827       False
# 3          0.932953       0.938827        True
# 4          0.932397       0.938827        True
# 5          0.931693       0.938827        True
# 6          0.931539       0.938827        True
# 7          0.931004       0.938827        True
# 8          0.931303       0.938827        True
# 9          0.915310       0.938827        True
# 10         0.919926       0.938827        True
# 11         0.915510       0.938827        True
# 12         0.917948       0.938827        True
# 13         0.916912       0.938827        True
# 14         0.909145       0.938827        True
# 15         0.908760       0.938827        True
# 16         0.907592       0.938827        True
# 17         0.905891       0.938827        True
# 18         0.904479       0.938827        True
# 19         0.898690       0.938827        True
# 20         0.906827       0.938827        True
# 21         0.908580       0.938827        True
# 22         0.896007       0.938827        True
# 23         0.910113       0.938827        True
# 24         0.907028       0.938827        True
# 25         0.904571       0.938827        True
# 26         0.895859       0.938827        True
# 27         0.913265       0.938827        True
# 28         0.913651       0.938827        True
# 29         0.913797       0.938827        True
# ...             ...            ...         ...
# 4729       0.920888       0.966422        True
# 4730       0.920777       0.966422        True
# 4731       0.920600       0.966422        True
# 4732       0.921094       0.966422        True
# 4733       0.920363       0.966422        True
# 4734       0.921005       0.966422        True
# 4735       0.920263       0.966422        True
# 4736       0.920573       0.966422        True
# 4737       0.919942       0.966422        True
# 4738       0.905219       0.966422        True
# 4739       0.921226       0.966422        True
# 4740       0.919832       0.966422        True
# 4741       0.903518       0.966422        True
# 4742       0.919649       0.966422        True
# 4743       0.919737       0.966422        True
# 4744       0.918149       0.966422        True
# 4745       0.903269       0.966422        True
# 4746       0.896412       0.966422        True
# 4747       0.897645       0.966422        True
# 4748       0.902016       0.966422        True
# 4749       0.901794       0.966422        True
# 4750       0.901882       0.966422        True
# 4751       0.895495       0.966422        True
# 4752       0.895672       0.966422        True
# 4753       0.895694       0.966422        True
# 4754       0.894211       0.966422        True
# 4755       0.894785       0.966422        True
# 4756       0.880286       0.966422        True
# 4757       0.894138       0.966422        True
# 4758       0.966422       0.966422       False
#
# [4759 rows x 3 columns]

# %%
plt.plot(df["mejor fitness"])
plt.plot(df["fitness total"])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="954.4">
