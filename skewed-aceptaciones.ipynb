# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
path = "C:\\Users\\Administrador\\Documents\\TFM-graficador\\ejecuciones\\entornos probabilisticos\\2_6-11-2019\\Caso1Id1m-01-01-2019\\VNS\\Trazas\\output5.csv"

# %%
df = pd.read_csv(path,
                 sep=';',
                 skiprows=[0],
                 names=[
                     "iteracion", "tiempo (ms)", "fitness total", "fitness 1",
                     "fitness 2", "fitness 3", "fitness 4", "tamaño",
                     "porcentajeMejora", "vecindad", "mejor fitness",
                     "distancia"
                 ])
df
# Out:
#       iteracion  tiempo (ms)  fitness total  fitness 1  fitness 2  fitness 3  \
# 0             0          651       0.609488   0.494499   0.987654   0.333333
# 1             1         1255       0.609488   0.494499   0.987654   0.333333
# 2             2         1851       0.609488   0.494499   0.987654   0.333333
# 3             3         1885       0.609488   0.494499   0.987654   0.333333
# 4             4         2021       0.645930   0.581868   0.959354   0.346154
# ...         ...          ...            ...        ...        ...        ...
# 4078       4078       599751       0.911358   0.000000   0.823701   0.916667
# 4079       4079       599931       0.912395   0.000000   0.826067   0.916667
# 4080       4080       599975       0.912395   0.000000   0.826067   0.916667
# 4081       4081       600075       0.911984   0.000000   0.823727   0.916667
# 4082       4082       600075       0.951773   0.000000   0.912269   1.000000
#
# ...

# %%
df2 = df.copy(deep=True)
df2.apply(lambda row: round(float(row["mejor fitness"]), 6), axis=1)
df2['diferentes'] = df.apply(
    lambda row: row["fitness total"] != row["mejor fitness"], axis=1)

df2[["fitness total", "mejor fitness", "diferentes"]]
# Out:
#       fitness total  mejor fitness  diferentes
# 0          0.609488       0.609488       False
# 1          0.609488       0.609488       False
# 2          0.609488       0.609488       False
# 3          0.609488       0.609488       False
# 4          0.645930       0.645930       False
# ...             ...            ...         ...
# 4078       0.911358       0.951773        True
# 4079       0.912395       0.951773        True
# 4080       0.912395       0.951773        True
# 4081       0.911984       0.951773        True
# 4082       0.951773       0.951773       False
#
# [4083 rows x 3 columns]

# %%
plt.plot(df["mejor fitness"], linewidth=1)
plt.plot(df["fitness total"], linewidth=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="984">

# %% [markdown]
# __________________________________
