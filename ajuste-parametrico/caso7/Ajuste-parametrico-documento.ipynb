# %% [markdown]
# # Ajuste Paramétrico

# %% [markdown]
# Hacemos las importaciones pertinentes y ajustamos el tamaño de las gráficas

# %%
# %run ../ajuste-parametrico.py

# %matplotlib notebook
plt.rcParams["figure.figsize"] = (15,9)
# Out:
# ['VND', 'RVNS', 'BVNS', 'GVNS', 'SVNS-optimo']
#              iteracion  tiempo (ms)  fitness total  fitness 1  fitness 2  \
# RVNS           24001.0      24532.0       0.941628        1.0   0.968114
# BVNS           29501.0     250053.1       0.943083        1.0   0.971272
# GVNS           29501.0     254229.0       0.943083        1.0   0.971272
# SVNS-optimo    29501.0     237868.7       0.943083        1.0   0.971272
# VND            13501.0      61742.6       0.943936        1.0   0.972398
#
#              fitness 3  fitness 4  tamaño  porcentajeMejora  mejor fitness  \
# RVNS          0.789474   0.696930    19.0          0.014035       0.941628
# BVNS          0.789474   0.706969    19.0          0.014912       0.943083
# GVNS          0.789474   0.706969    19.0          0.014912       0.943083
# SVNS-optimo   0.789474   0.706969    19.0          0.014912       0.943083
# VND           0.789474   0.716131    19.0          0.005848       0.943936
#
#              distancia  restricciones incumplidas  reinicios  std. iteracion  \
# RVNS         -1.000000                     10.905     3923.5     6992.058988
# BVNS         -1.000000                      9.825     4848.5    10916.348596
# GVNS         -1.000000                      9.825     4848.5    10916.348596
# SVNS-optimo   0.002251                      9.825     4848.5    10916.348596
# VND          -1.000000                      9.440     2198.7     4116.363012
#
#              std. tiempo (ms)  std. fitness total  std. tamaño  \
# RVNS              6548.685992            0.001740          0.0
# BVNS             91265.033060            0.001714          0.0
# GVNS             90993.792019            0.001714          0.0
# SVNS-optimo      84481.420510            0.001714          0.0
# VND              17300.350126            0.001774          0.0
#
#              std. restricciones incumplidas
# RVNS                               2.296791
# BVNS                               1.932507
# GVNS                               1.932507
# SVNS-optimo                        1.932507
# VND                                1.609486

# %%
plt.rcParams["figure.figsize"] = (15,9)
BASE_URL = "C:\\Users\\GL753V\\Documents\\Projects\\TFM-graficador\\ejecuciones\\ajuste-parametrico\\caso7\\"

# %% [markdown]
# El orden de los parámetros ordenados por robustez es:
# 1.	Tipo de VNS<br>
#     Para skewed:<br>
#     1.1.	Alpha <br>
#     1.2.	Función de distancia <br>
# 2.	Estructuras de vecindad y orden<br>
# 3.	Naturaleza del orden de los entornos (determinísticos o probabilísticos)<br>
#     Para Probabilístico:<br>
#     3.1.	Probabilidad de diversificación<br>
#     3.2.	Variación de la probabilidad de diversificación <br>
#     3.3.	Numero de iteraciones sin variar la probabilidad de diversificación
# 4.	Número de iteraciones para comprobar el porcentaje de mejoría (ciclos)
# 5.	Porcentaje mínimo de mejoría
# 6.	Número máximo de iteraciones sin mejora para la búsqueda local
# 7.	Porcentaje mínimo de mejoría para la búsqueda local

# %% [markdown]
# ## Tipo de VNS
# Empezamos el ajuste con el tipo de VNS. Para ello probamos diferentes valores para alpha y la funcion de distancia cuando ejecutemos el SVNS

# %% [markdown]
# ### Alpha y función de distancia

# %% [markdown]
# Para poder ajustar el alpha tenemos dos posibilidades, empleando como función de distancia el número de slots y empleando la diferencia del valor de los fitness

# %% [markdown]
# #### Funcion de distancia: Número de Slots

# %%
base_path = BASE_URL + "1-TipoVNS\\SVNS\\slots"
sub_paths = get_subpaths(base_path, float)

parametro="SVNS Alpha slots"
out_path="1-1 "+parametro+"/"

# %%
ajuste_parametrico(base_path, sub_paths, out_path, parametro, "tiempo (ms)",
                   {"ordenados": True, "multiple": False}, {"ordenados": True, "multiple": True})
# Out:
# ['-0.5', '0.25', '0.5', '1.0', '1.25', '1.5', '2.0', '5.0', '10.0', '15.0', '20.0', '30.0', '40.0', '50.0']
#       iteracion  tiempo (ms)  fitness total  fitness 1  fitness 2  fitness 3  \
# 0.5             0.005054          0.0                       14.917292
# 20.0            0.005412          0.0                        9.545119
# 2.0             0.005412          0.0                        9.545119
# 5.0             0.005412          0.0                        9.545119
# 1.25            0.005412          0.0                        9.545119
# 1.5             0.005412          0.0                        9.545119
# 30.0            0.005412          0.0                        9.545119
# 40.0            0.005412          0.0                        9.545119
# 10.0            0.005412          0.0                        9.545119
# 50.0            0.005412          0.0                        9.545119
# 15.0            0.005412          0.0                        9.545119
# 1.0             0.005412          0.0                        9.545119
# 0.25            0.004581          0.0                       12.460414

# %% [markdown]
# #### Función de distancia: Fitness

# %%
base_path = BASE_URL + "1-TipoVNS\\SVNS\\fitness"
sub_paths = get_subpaths(base_path, key=float)

parametro="SVNS Alpha fitness"
out_path="1-2 "+parametro+"/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro)
# Out:
# ['0.5', '1.0', '1.5', '2.0']
#      distancia  fitness 1  fitness 2  fitness 3  fitness 4  fitness total  \
# 2.0   0.005935        1.0   0.832657   0.403846   0.612759       0.841343
# 1.0   0.003376        1.0   0.976842   0.692308   0.683724       0.928617
# 0.5   0.005124        1.0   0.978401   0.692308   0.684207       0.929067
# 1.5        NaN        NaN        NaN        NaN        NaN            NaN
#
#      iteracion  mejor fitness  porcentajeMejora  reinicios  \
# 2.0   840843.5       0.868602          0.005914        1.0
# 1.0    23001.0       0.928617          0.018838     3780.2
# 0.5    29501.0       0.929067          0.016244     4840.4
# 1.5     1890.0            NaN               NaN        NaN
#
#      restricciones incumplidas  std. fitness total  std. iteracion  \
# 2.0                  47.483544            0.038550   430143.661597
# 1.0                  10.837785            0.002662     8881.941730
# 0.5                  10.108354            0.001959     9264.628073
# 1.5                        NaN                 NaN             NaN
#
#      std. restricciones incumplidas  std. tamaño  std. tiempo (ms)  tamaño  \
# 2.0                             NaN          NaN      7.553189e+06    26.0
# 1.0                        4.292216          0.0      1.100843e+05    26.0
# 0.5                        2.683903          0.0      1.132794e+05    26.0
# 1.5                             NaN          NaN               NaN     NaN
#
#      tiempo (ms)  vecindad
# 2.0   15327324.0       NaN
# 1.0     282962.0       NaN
# 0.5     363173.4       NaN
# 1.5          NaN       NaN

# %% [markdown]
# $Función Distancia = \Delta fitness$ da mejores resultados en menos tiempo que la función por slots

# %% [markdown]
# #### Tipo de VNS

# %%
base_path = BASE_URL + "1-TipoVNS"
sub_paths = ["VND", "RVNS", "BVNS", "GVNS"]

parametro="Tipo VNS"
out_path="1-3 "+parametro+"/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro)
# Out:
# ['VND', 'RVNS', 'BVNS', 'GVNS']
#       iteracion  tiempo (ms)  fitness total  fitness 1  fitness 2  fitness 3  \
# RVNS    22501.0      38927.6       0.928107        1.0   0.975345   0.692308
# BVNS    23001.0     285327.1       0.928617        1.0   0.976842   0.692308
# GVNS    23001.0     282490.2       0.928617        1.0   0.976842   0.692308
# VND     15001.0     128883.0       0.931118        1.0   0.981976   0.692308
#
#       fitness 4  tamaño  porcentajeMejora  mejor fitness  distancia  \
# RVNS   0.681966    26.0          0.017172       0.928107       -1.0
# BVNS   0.683724    26.0          0.018838       0.928617       -1.0
# GVNS   0.683724    26.0          0.018838       0.928617       -1.0
# VND    0.702310    26.0          0.008194       0.931118       -1.0
#
#       restricciones incumplidas  reinicios  std. iteracion  std. tiempo (ms)  \
# RVNS                  11.538354     3691.2     4249.182928       7492.896980
# BVNS                  10.837785     3780.2     8881.941730     113370.908824
# GVNS                  10.837785     3780.2     8881.941730     110051.931292
# VND                    8.435253     2457.6     5773.502692      47833.861625
#
#       std. fitness total  std. tamaño  std. restricciones incumplidas
# RVNS            0.001956          0.0                        3.539690
# BVNS            0.002662          0.0                        4.292216
# GVNS            0.002662          0.0                        4.292216
# VND             0.000802          0.0                        1.611209

# %% [markdown]
# Podemos observar que los resultados del SVNS son muy similares a todos los demas, y si tenemos en cuenta que es el necesita mayor coste computacional, podemos descartarlo.
# <br>
# En cuanto a los demás, si bien las diferencias nuevamente son mínimas, el mejor de todos es el VND, que es además el más sencillo de todos, es decir, el de menor coste computacional.
#
# $$Tipo VNS = VND$$

# %% [markdown]
# ## Estructuras de vecindad y orden

# %% [markdown]
# Las estructuras de vecindad propuestas son:
#
# a) movRejilla, movMaxCarga.1 ... movMaxCarga.4, movLibre
# <br>
# b) movMaxCarga, movRejilla.1 ... movRejilla.4, movLibre
# <br>
# c) movMaxCarga.1 ... movMaxCarga.4, movRejilla.1 ... movRejilla.4, movLibre
# <br>
# d) movRejilla.1 ... movRejilla.4, movMaxCarga.1 ... movMaxCarga.4, movLibre
# <br>

# %%
base_path = BASE_URL + "2-OrdenEntornos"
sub_paths = get_subpaths(base_path)

parametro="Orden Entornos"
out_path="2 "+parametro+"/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro)

# %% [markdown]
# ## Naturaleza del orden de los entornos

# %% [markdown]
# ### Probabilístico

# %% [markdown]
# #### Probabilidad de diversificación

# %%
base_path = BASE_URL + "3-Vecindades\\probabilisticos\\prob"
sub_paths = get_subpaths(base_path, key=float)

parametro = "Probabilidad Diversificacion"
out_path = "3-1 " + parametro + "/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro)

# %% [markdown]
# #### Variación de la probabilidad de diversificación

# %%
base_path = BASE_URL + "3-Vecindades\\probabilisticos\\var"
sub_paths = get_subpaths(base_path, key=float)

parametro = "Variacion Probabilidad Diversificacion"
out_path = "3-2 " + parametro + "/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro)

# %% [markdown]
# #### Numero de iteraciones sin variar la probabilidad de diversificación

# %%
base_path = BASE_URL + "3-Vecindades\\probabilisticos\\iter"
sub_paths = get_subpaths(base_path, key=float)

parametro = "Ciclos Probabilidad Diversificacion"
out_path = "3-3 " + parametro + "/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro)

# %% [markdown]
# ### Determinista vs Probabilistico

# %%
base_path = BASE_URL + "3-Vecindades\\TipoEntornos"
sub_paths = ["determinista", "probabilistico"]
#sub_paths = get_subpaths(base_path)

parametro = "Naturaleza Orden Entornos"
out_path = "3-4 " + parametro + "/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro)

# %% [markdown]
# ## Número de iteraciones para comprobar el porcentaje de mejoría (ciclos)

# %%
base_path = BASE_URL + "4-NumCiclosPorcentajeMejoria"
sub_paths = get_subpaths(base_path, key=int)
parametro = "Numero Iteraciones para comprobar porcentaje de mejoría"
out_path = "4 " + parametro + "/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro, {"ordenados": False, "multiple": True})

# %% [markdown]
# ## Porcentaje mínimo de mejoría

# %%
base_path = BASE_URL + "5-PorcentajeMinimoMejoria"
sub_paths = get_subpaths(base_path, key=float)
parametro = "Porcentaje mínimo de mejoría"
out_path = "5 " + parametro + "/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro, 
                   {"ordenados":False, "multiple":False}, {"ordenados":False, "multiple":True}
                  )

# %% [markdown]
# ## Número máximo de iteraciones sin mejora en la Búsqueda Local

# %%
base_path = BASE_URL + "6-NumMaxIteracionesSinMejoraBusquedaLocal"
sub_paths = get_subpaths(base_path, key=int)
parametro = "Número máximo de iteraciones sin mejora en la Búsqueda Local"
out_path = "6 " + parametro + "/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro, {"multiple":True, "ordenados":False})

# %% [markdown]
# ## Porcentaje mínimo de mejoría en la Búsqueda Local

# %%
base_path = BASE_URL + "7-PorcentajeMinimoMejoriaBusquedaLocal"
sub_paths = get_subpaths(base_path, key=float)
parametro = "Porcentaje mínimo de mejoría en la Búsqueda Local"
out_path = "7 " + parametro + "/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro)
