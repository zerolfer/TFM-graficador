# %% [markdown]
# # Ajuste Paramétrico

# %% [markdown]
# Hacemos las importaciones pertinentes y ajustamos el tamaño de las gráficas

# %%
# %run ../ajuste-parametrico.py

# %matplotlib notebook
plt.rcParams["figure.figsize"] = (15,9)

# %%
plt.rcParams["figure.figsize"] = (15,9)
BASE_URL = "C:\\Users\\GL753V\\Documents\\Projects\\TFM-graficador\\ejecuciones\\ajuste-parametrico\\caso5\\primera-iteracion\\"

# %% [markdown]
# El orden de los parámetros ordenados por robustez es:
# 1.	Tipo de VNS<br>
#     Para skewed:<br>
#     1.1.	Alpha <br>
#     1.2.	Función de distancia <br>
# 2.	Estructuras de vecindad y orden<br>
# 3.	Naturaleza del orden de los entornos (determinísticos o probabilísticos)<br>
#     Para Probabilístico:<br>
#     3.1.	Probabilidad de diversificación<br>
#     3.2.	Variación de la probabilidad de diversificación <br>
#     3.3.	Numero de iteraciones sin variar la probabilidad de diversificación
# 4.	Número de iteraciones para comprobar el porcentaje de mejoría (ciclos)
# 5.	Porcentaje mínimo de mejoría
# 6.	Número máximo de iteraciones sin mejora para la búsqueda local
# 7.	Porcentaje mínimo de mejoría para la búsqueda local

# %% [markdown]
# ## Tipo de VNS
# Empezamos el ajuste con el tipo de VNS. Para ello probamos diferentes valores para alpha y la funcion de distancia cuando ejecutemos el SVNS

# %% [markdown]
# ### Alpha y función de distancia

# %% [markdown]
# Para poder ajustar el alpha tenemos dos posibilidades, empleando como función de distancia el número de slots y empleando la diferencia del valor de los fitness

# %% [markdown]
# #### Funcion de distancia: Número de Slots

# %%
base_path = BASE_URL + "1-TipoVNS\\SVNS\\slots"
sub_paths = get_subpaths(base_path, float)

parametro="SVNS Alpha slots"
out_path="1-1 "+parametro+"/"

# %%
ajuste_parametrico(base_path, sub_paths, out_path, parametro)
# Out:
# ['1.0', '2.0']
#      iteracion  tiempo (ms)  fitness total  fitness 1  fitness 2  fitness 3  \
# 1.0   170671.0    3352049.0       0.871365        1.0   0.000000        NaN
# 2.0    18207.0     170500.0       0.882978        1.0   0.970078   0.368421
#
#      fitness 4  tamaño  porcentajeMejora  vecindad  mejor fitness  distancia  \
# 1.0        NaN     NaN               NaN       NaN            NaN        NaN
# 2.0        NaN     NaN               NaN       NaN            NaN        NaN
#
#      restricciones incumplidas  reinicios
# 1.0                        NaN        NaN
# 2.0                        NaN        NaN

# %% [markdown]
# #### Función de distancia: Fitness

# %%
base_path = BASE_URL + "1-TipoVNS\\SVNS\\fitness"
sub_paths = get_subpaths(base_path, key=float)

parametro="SVNS Alpha fitness"
out_path="1-2 "+parametro+"/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro)
# Out:
# ['-0.5', '0.25', '0.5', '1.0', '1.25', '1.5', '2.0', '5.0', '10.0']
#       distancia  fitness 1  fitness 2  fitness 3  fitness 4  fitness total  \
# 2.0         NaN        1.0   0.958618   0.289474   0.757937       0.867407
# 1.5         NaN        NaN        NaN        NaN        NaN       0.875798
# 10.0        NaN        NaN        NaN        NaN        NaN       0.879157
# 5.0         NaN        NaN        NaN        NaN        NaN       0.881001
# 1.25        NaN        1.0   0.964782   0.368421   0.777778       0.882421
# -0.5   0.002344        1.0   0.993509   0.473684   0.835714       0.909443
# 1.0    0.002344        1.0   0.993509   0.473684   0.835714       0.909443
# 0.25   0.001245        1.0   0.993450   0.473684   0.840212       0.909697
# 0.5    0.001245        1.0   0.993450   0.473684   0.840212       0.909697
#
#       iteracion  mejor fitness  porcentajeMejora  reinicios  \
# 2.0    160932.0            NaN          2.279637        NaN
# 1.5    171730.0            NaN               NaN        NaN
# 10.0   169224.0            NaN               NaN        NaN
# 5.0    171094.0            NaN               NaN        NaN
# 1.25   121157.0            NaN          2.489474        NaN
# -0.5    11001.0       0.909443          0.008730        NaN
# 1.0     11001.0       0.909443          0.008730        NaN
# 0.25    10501.0       0.909697          0.003968        NaN
# 0.5     10501.0       0.909697          0.003968        NaN
#
#       restricciones incumplidas  tamaño  tiempo (ms)  vecindad
# 2.0                         NaN    19.0   17101005.0       NaN
# 1.5                         NaN     NaN   25667189.0       NaN
# 10.0                        NaN     NaN    2680579.0       NaN
# 5.0                         NaN     NaN    3999281.0       NaN
# 1.25                        NaN    19.0    1241093.0       NaN
# -0.5                       2.22    19.0      40243.9       NaN
# 1.0                        2.22    19.0      40026.2       NaN
# 0.25                       2.24    19.0      38708.3       NaN
# 0.5                        2.24    19.0      38347.3       NaN

# %% [markdown]
# En vista de los resultados anteriores, podemos decir que los resultados son mejores empleando como función de distancia la diferencia entre los fitness, con un apha de 1
# $$\alpha=1$$
# $$Función Distancia = \Delta fitness$$

# %% [markdown]
# #### Tipo de VNS

# %%
base_path = BASE_URL + "1-TipoVNS"
sub_paths = ["VND", "RVNS", "BVNS", "GVNS"]

parametro="Tipo VNS"
out_path="1-3 "+parametro+"/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro)
# Out:
# ['VND', 'RVNS', 'BVNS', 'GVNS']
#       iteracion  tiempo (ms)  fitness total  fitness 1  fitness 2  fitness 3  \
# VND     10001.0      37642.1       0.918376    0.94328   0.941317   0.900952
# RVNS    14001.0      12730.9       0.952438    1.00000   0.958596   0.900000
# BVNS    21501.0     182084.2       0.965241    1.00000   0.992208   0.900000
# GVNS    21501.0     187290.5       0.965241    1.00000   0.992208   0.900000
#
#       fitness 4  tamaño  porcentajeMejora  mejor fitness  distancia  \
# VND    0.642864    20.2          0.000268       0.918376       -1.0
# RVNS   0.643622    20.0          0.006155       0.952438       -1.0
# BVNS   0.705754    20.0          0.013916       0.965241       -1.0
# GVNS   0.705754    20.0          0.013916       0.965241       -1.0
#
#       restricciones incumplidas  reinicios
# VND                   21.356111     1657.4
# RVNS                  14.905556     2305.4
# BVNS                   2.805000     3528.8
# GVNS                   2.805000     3528.8

# %% [markdown]
# Podemos observar que los resultados del SVNS son muy similares a todos los demas, y si tenemos en cuenta que es el necesita mayor coste computacional, podemos descartarlo.
# <br>
# En cuanto a los demás, si bien las diferencias nuevamente son mínimas, el mejor de todos es el VND, que es además el más sencillo de todos, es decir, el de menor coste computacional.
#
# $$Tipo VNS = VND$$

# %% [markdown]
# ## Estructuras de vecindad y orden

# %% [markdown]
# Las estructuras de vecindad propuestas son:
#
# a) movRejilla, movMaxCarga.1 ... movMaxCarga.4, movLibre
# <br>
# b) movMaxCarga, movRejilla.1 ... movRejilla.4, movLibre
#
#       fitness 4  tamaño  porcentajeMejora  mejor fitness  distancia  \
# 1      0.687065    20.0          0.010194       0.962759       -1.0
# 5      0.692417    20.0          0.018466       0.964216       -1.0
# 10     0.692417    20.0          0.018466       0.964216       -1.0
# 25     0.692417    20.0          0.018466       0.964216       -1.0
# 50     0.692417    20.0          0.018466       0.964216       -1.0
# 60     0.692417    20.0          0.018466       0.964216       -1.0
# 65     0.692417    20.0          0.018466       0.964216       -1.0
# 70     0.692417    20.0          0.018466       0.964216       -1.0
# 75     0.692417    20.0          0.018466       0.964216       -1.0
# 80     0.692417    20.0          0.018466       0.964216       -1.0
# 85     0.692417    20.0          0.018466       0.964216       -1.0
# 90     0.692417    20.0          0.018466       0.964216       -1.0
# 95     0.692417    20.0          0.018466       0.964216       -1.0
# 100    0.692417    20.0          0.018466       0.964216       -1.0
# 1000   0.692417    20.0          0.018466       0.964216       -1.0
#
#       restricciones incumplidas  reinicios
# 1                      4.619444     2027.7
# 5                      3.105000     1968.0
# 10                     3.105000     1968.0
# 25                     3.105000     1968.0
# 50                     3.105000     1968.0
# 60                     3.105000     1968.0
# 65                     3.105000     1968.0
# 70                     3.105000     1968.0
# 75                     3.105000     1968.0
# 80                     3.105000     1968.0
# 85                     3.105000     1968.0
# 90                     3.105000     1968.0
# 95                     3.105000     1968.0
# 100                    3.105000     1968.0
# 1000                   3.105000     1968.0

# %% [markdown]
# ### Determinista vs Probabilistico

# %%
base_path = BASE_URL + "3-Vecindades\\TipoEntornos"
sub_paths = ["determinista", "probabilistico"]
#sub_paths = get_subpaths(base_path)

parametro = "Naturaleza Orden Entornos"
out_path = "3-4 " + parametro + "/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro)
# Out:
# ['determinista', 'probabilistico']
#                 iteracion  tiempo (ms)  fitness total  fitness 1  fitness 2  \
# determinista      19501.0     133747.4       0.963213        1.0   0.988838
# probabilistico    20001.0     138787.1       0.964362        1.0   0.991389
#
#                 fitness 3  fitness 4  tamaño  porcentajeMejora  mejor fitness  \
# determinista          0.9   0.687110    20.0          0.012578       0.963213
# probabilistico        0.9   0.694781    20.0          0.017395       0.964362
#
#                 distancia  restricciones incumplidas  reinicios
# determinista         -1.0                   4.018333     2119.2
# probabilistico       -1.0                   3.100000     2191.9

# %% [markdown]
# ## Número de iteraciones para comprobar el porcentaje de mejoría (ciclos)

# %%
base_path = BASE_URL + "4-NumCiclosPorcentajeMejoria"
sub_paths = get_subpaths(base_path, key=int)
parametro = "Numero Iteraciones para comprobar porcentaje de mejoría"
out_path = "4 " + parametro + "/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro, {"ordenados": False, "multiple": True})
# Out:
# ['50', '100', '1000', '5000', '6000', '7000', '10000', '20000', '25000', '30000', '40000', '45000', '50000']
#        iteracion  tiempo (ms)  fitness total  fitness 1  fitness 2  fitness 3  \
# 50         161.0       1447.9       0.953365        1.0   0.969216        0.9
# 100        371.0       3114.3       0.954637        1.0   0.972003        0.9
# 1000      5901.0      43161.9       0.962249        1.0   0.988569        0.9
# 5000     18001.0     125521.2       0.964216        1.0   0.991375        0.9
# 10000    34001.0     227939.8       0.964583        1.0   0.991653        0.9
# 7000     24501.0     166505.3       0.964587        1.0   0.991944        0.9
# 6000     21601.0     146992.2       0.964723        1.0   0.992222        0.9
# 20000    54001.0     348038.6       0.965068        1.0   0.991667        0.9
# 25000    65001.0     425345.1       0.965182        1.0   0.992761        0.9
# 40000    96001.0     597773.3       0.965296        1.0   0.991944        0.9
# 45000   117001.0     708419.2       0.965741        1.0   0.994167        0.9
# 30000    84001.0     523880.9       0.965797        1.0   0.994444        0.9
# 50000   140001.0     837961.0       0.966081        1.0   0.994444        0.9
#
#        fitness 4  tamaño  porcentajeMejora  mejor fitness  distancia  \
#
itness 4  tamaño  porcentajeMejora  mejor fitness  distancia  \
# 3    0.681534    20.0          0.000000       0.962684       -1.0
# 2    0.701829    20.0          0.001338       0.964860       -1.0
# 1    0.698037    20.0          0.000000       0.965382       -1.0
# 4    0.703501    20.0          0.000000       0.965523       -1.0
# 5    0.703167    20.0          0.001338       0.965690       -1.0
# 6    0.709523    20.0          0.000000       0.965694       -1.0
# 8    0.714764    20.0          0.001338       0.966198       -1.0
# 7    0.710303    20.0          0.000669       0.966306       -1.0
# 9    0.712756    20.0          0.002007       0.966453       -1.0
# 10   0.717774    20.0          0.000669       0.966754       -1.0
# 20   0.717774    20.0          0.000000       0.967129       -1.0
# 15   0.720785    20.0          0.000669       0.967310       -1.0
#
#     restricciones incumplidas  reinicios
# 3                    4.277778   14968.00
# 2                    3.000000   11214.75
# 1                    2.000000   13719.25
# 4                    2.250000   18711.75
# 5                    2.000000   17461.50
# 6                    2.502778   22464.50
# 8                    2.250000   16215.25
# 7                    1.750000   19964.25
# 9                    1.750000   21217.50
# 10                   1.750000   18714.25
# 20                   1.250000   27467.50
# 15                   1.250000   27468.50

# %% [markdown]
# ## Porcentaje mínimo de mejoría en la Búsqueda Local

# %%
base_path = BASE_URL + "7-PorcentajeMinimoMejoriaBusquedaLocal"
sub_paths = get_subpaths(base_path, key=float)
parametro = "Porcentaje mínimo de mejoría en la Búsqueda Local"
out_path = "7 " + parametro + "/"

ajuste_parametrico(base_path, sub_paths, out_path, parametro)
# Out:
# ['0.0', '0.005', '0.01', '0.05', '0.1', '0.5', '1.0', '5.0', '10.0']
#        iteracion  tiempo (ms)  fitness total  fitness 1  fitness 2  fitness 3  \
# 0.5     189001.0    1051852.8       0.960020        1.0   0.978213        0.9
# 0.01    180001.0    1002766.8       0.965332        1.0   0.992216        0.9
# 5.0     162001.0     892460.6       0.965695        1.0   0.992750        0.9
# 10.0    162001.0     893173.2       0.965695        1.0   0.992750        0.9
# 0.05    153001.0     855966.4       0.965832        1.0   0.993889        0.9
# 1.0     162001.0     905521.6       0.965960        1.0   0.992778        0.9
# 0.005   144001.0     827163.2       0.966046        1.0   0.993333        0.9
# 0.1     261001.0    1480954.8       0.966084        1.0   0.995000        0.9
# 0.0     270001.0    1547553.0       0.966817        1.0   0.995000        0.9
#
#        fitness 4  tamaño  porcentajeMejora  mejor fitness  distancia  \
# 0.5     0.681713    20.0          0.000000       0.960020       -1.0
# 0.01    0.707226    20.0          0.000535       0.965332       -1.0
# 5.0     0.710883    20.0          0.000535       0.965695       -1.0
# 10.0    0.710883    20.0          0.000535       0.965695       -1.0
# 0.05    0.708029    20.0          0.000000       0.965832       -1.0
# 1.0     0.715165    20.0          0.001070       0.965960       -1.0
# 0.005   0.714095    20.0          0.000000       0.966046       -1.0
# 0.1     0.707226    20.0          0.000000       0.966084       -1.0
# 0.0     0.719447    20.0          0.000000       0.966817       -1.0
#
#        restricciones incumplidas  reinicios
# 0.5                     7.843333    20978.4
# 0.01                    2.802222    19964.4
# 5.0                     2.610000    17960.6
# 10.0                    2.610000    17960.6
# 0.05                    2.200000    16963.6
# 1.0                     2.600000    17962.6
# 0.005                   2.400000    15963.4
# 0.1                     1.800000    28958.4
# 0.0                     1.800000    29960.4
